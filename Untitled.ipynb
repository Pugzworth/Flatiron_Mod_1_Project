# %%
#Webscraping boxofficemojo.com

import pandas as pd

import requests
from bs4 import BeautifulSoup
import lxml.html as lh

# %%
years=[str(a) for a in range(2014,2020)]
df_list=[]

for year in years:
        url = 'https://www.boxofficemojo.com/month/by-year/?grossesOption=calendarGrosses'
        #res = requests.get(url)

        r=requests.get(url)
        html = BeautifulSoup(r.content, 'html.parser')
       # print(html)
        month = html.find('span', class_ = "a-color-state")
        #print(month)
       # p=BeautifulSoup(r.text,'html.parser')
        
        #tr_elements = html.xpath('//tr')
        
        #print(tr_elements)
        
        df = pd.read_html('https://www.boxofficemojo.com/month/by-year/?grossesOption=calendarGrosses')
        df

# %%
pwd
# Out:
# '/Users/lenaya/DS/Flatiron_Mod_1_Project'

# %%
df_2019 = pd.read_html('https://www.boxofficemojo.com/month/by-year/2019/?grossesOption=calendarGrosses')[0]
df_2019
#df_2019.to_csv(r'/Users/lenaya/DS/Flatiron_Mod_1_Project/df_2019.csv')
# Out:
#         Month Cumulative Gross % of Year  Releases     Average  \
# 0    December   $1,148,160,515     10.1%       167  $6,875,212
# 1    November     $959,201,231      8.5%       187  $5,129,418
# 2     October     $781,620,115      6.9%       216  $3,618,611
# 3   September     $686,794,246      6.1%       204  $3,366,638
# 4      August     $837,630,353      7.4%       211  $3,969,812
# 5        July   $1,288,192,055     11.4%       189  $6,815,830
# 6        June   $1,149,119,141     10.2%       193  $5,953,985
# 7         May   $1,077,678,483      9.5%       225  $4,789,682
# 8       April   $1,034,980,308      9.1%       218  $4,747,616
# 9       March     $962,714,895      8.5%       191  $5,040,392
# 10   February     $624,461,550      5.5%       146  $4,277,133
# 11    January     $812,849,718      7.2%       161  $5,048,756
#
#                                        #1 Release Genre Budget Running Time  \
# ...

# %%
print(res.raise_for_status())
soup = BeautifulSoup(res.text)
type(soup)
# Out:
# None
# bs4.BeautifulSoup

# %%
 print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title dir="ltr">
#    2020 Monthly Box Office - Box Office Mojo
#   </title>
#   <meta content="2020 Monthly Box Office" name="title"/>
#   <meta content="Box Office Mojo" property="og:site_name"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
df_ww = pd.DataFrame()
for year in range(2014,2020):
    
    url_1 = f'https://www.boxofficemojo.com/year/world/{year}/'
    df_ww_year = pd.read_html(url_1)[0]
    df_ww_year
    df_ww = pd.concat([df_ww, df_ww_year])

# %%
df_ww.head()
#df_ww.to_csv(r'/Users/lenaya/DS/Flatiron_Mod_1_Project/df_ww.csv')
# Out:
#    Rank                              Release Group       Worldwide  \
# 0     1            Transformers: Age of Extinction  $1,104,054,072
# 1     2  The Hobbit: The Battle of the Five Armies    $956,019,788
# 2     3                    Guardians of the Galaxy    $772,776,600
# 3     4                                 Maleficent    $758,410,378
# 4     5      The Hunger Games: Mockingjay - Part 1    $755,356,711
#
#        Domestic      %       Foreign    %.1
# 0  $245,439,076  22.2%  $858,614,996  77.8%
# 1  $255,119,788  26.7%  $700,900,000  73.3%
# 2  $333,176,600  43.1%  $439,600,000  56.9%
# 3  $241,410,378  31.8%  $517,000,000  68.2%
# 4  $337,135,885  44.6%  $418,220,826  55.4%
