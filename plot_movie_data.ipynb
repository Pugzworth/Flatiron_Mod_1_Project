# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df_1 = pd.read_csv('CSVs/MovieDB_df.csv')

# %%
df_1.sort_values(by=['budget'], ascending=False)
# Out:
#       Unnamed: 0      id                                       genre_ids  \
# 4793       13950  227973  ['Adventure', 'Animation', 'Comedy', 'Family']
# 5504       15612  298721                            ['Drama', 'Fantasy']
# 3430       10083    1734              ['Action', 'Adventure', 'Fantasy']
# 16            19  359724                             ['Action', 'Drama']
# 3369        9902  126889       ['Horror', 'Science Fiction', 'Thriller']
# ...          ...     ...                                             ...
# 2781        8295  455675                                     ['Western']
# 2780        8291  432087                             ['Comedy', 'Drama']
# 2778        8289  484862               ['Action', 'Animation', 'Comedy']
# 2777        8288  516038                                      ['Comedy']
# 3456       10154  537971                        ['Drama', 'Documentary']
#
#                                     original_title  \
# 4793                             The Peanuts Movie
# 5504                                 รักที่ขอนแก่น
# 3430                             The Mummy Returns
# 16                                  Ford v Ferrari
# 3369                               Alien: Covenant
# ...                                            ...
# 2781                                        Hickok
# 2780                               Ce qui nous lie
# 2778  Scooby-Doo! & Batman: The Brave and the Bold
# 2777                         Fary Is the New Black
# 3456                                           Mia
#
#                                              title release_date  popularity  \
# 4793                             The Peanuts Movie   2015-11-01      10.825
# 5504                         Cemetery of Splendour   2015-09-02       5.113
# 3430                             The Mummy Returns   2001-05-04      14.584
# 16                                  Ford v Ferrari   2019-11-13      63.028
# 3369                               Alien: Covenant   2017-05-09      27.326
# ...                                            ...          ...         ...
# 2781                                        Hickok   2017-07-07       5.468
# 2780                              Back to Burgundy   2017-06-14       6.719
# 2778  Scooby-Doo! & Batman: The Brave and the Bold   2018-01-09       6.345
# 2777                         Fary Is the New Black   2018-04-03       5.499
# 3456                                           Mia   2017-12-17      11.995
#
#       vote_average  vote_count          budget          revenue     imdb_id
# 4793          66.0         981  $99,000,000.00  $246,233,113.00   tt2452042
# 5504          53.0          78     $980,000.00            $0.00   tt2818654
# 3430          62.0        4382  $98,000,000.00  $433,013,274.00   tt0209163
# 16            78.0        1722  $97,600,000.00  $220,803,003.00   tt1950186
# 3369          59.0        5471  $97,000,000.00  $232,380,243.00   tt2316204
# ...            ...         ...             ...              ...         ...
# 2781          50.0          50           $0.00            $0.00   tt6334884
# 2780          70.0         247           $0.00            $0.00   tt5247704
# 2778          65.0          54           $0.00            $0.00   tt7578566
# 2777          70.0          59           $0.00            $0.00   tt8201924
# 3456          80.0           1           $0.00            $0.00  tt10540298
#
# [6913 rows x 12 columns]

# %%
df_1=df_1.drop('Unnamed: 0', axis =1)

# %%
df_2 = pd.read_csv('df_imdb_fin.csv')

# %%
df_2.head()
# Out:
#       imdb_id                  originalTitle  startYear         genres  \
# 0  tt10551082                Shattered Waves     2017.0  Drama,History
# 1  tt11214476  The Destiny Samaj of Banjaraa     2019.0          Drama
# 2  tt10378512               Path of the Daff     2019.0    Documentary
# 3  tt10620492                      Khoussouf     2016.0          Drama
# 4  tt10608660  Identitas - Uguali ma diversi     2019.0    Documentary
#
#    averageRating  numVotes
# 0           10.0         8
# 1           10.0         5
# 2           10.0        11
# 3           10.0         8
# 4           10.0         6

# %%
df_2.rename(columns={'imdb_id	':'imdb_id'}, inplace=True)

# %%
df_2=df_2.drop('Unnamed: 0', axis =1)

# %%
df_tot = df_1.merge(df_2)

# %%
df_tot.head()
# Out:
#        id                                          genre_ids  \
# 0  475303                              ['Comedy', 'Romance']
# 1  512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2  419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3  496243                    ['Comedy', 'Drama', 'Thriller']
# 4  330457               ['Adventure', 'Animation', 'Family']
#
#             original_title                    title release_date  popularity  \
# 0  A Rainy Day in New York  A Rainy Day in New York   2019-07-26    1305.559
# 1  Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04     272.710
# 2                 Ad Astra                 Ad Astra   2019-09-17     271.489
# 3                      기생충                 Parasite   2019-05-30     148.987
# 4                Frozen II                Frozen II   2019-11-20     124.257
#
#    vote_average  vote_count           budget            revenue    imdb_id  \
# 0          67.0         591            $0.00              $0.00  tt7139936
# 1          68.0        1901  $125,000,000.00    $310,830,000.00  tt7975244
# 2          60.0        2483   $87,500,000.00    $127,175,922.00  tt2935510
# 3          86.0        4756   $11,363,000.00    $201,055,038.00  tt6751668
# 4          71.0        2614   $33,000,000.00  $1,330,764,959.00  tt4520988
#
#              originalTitle  startYear                      genres  \
# 0  A Rainy Day in New York     2019.0              Comedy,Romance
# 1  Jumanji: The Next Level     2019.0     Action,Adventure,Comedy
# 2                 Ad Astra     2019.0     Adventure,Drama,Mystery
# 3             Gisaengchung     2019.0       Comedy,Drama,Thriller
# 4                Frozen II     2019.0  Adventure,Animation,Comedy
#
#    averageRating  numVotes
# 0            6.6     15792
# 1            6.9     90466
# 2            6.6    147305
# 3            8.6    288268
# 4            7.1     77968

# %%
df_tot.drop(df_tot.index[df_tot['revenue'] == '$0.00'], inplace = True)

# %%
df_tot.head()
# Out:
#        id                                          genre_ids  \
# 1  512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2  419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3  496243                    ['Comedy', 'Drama', 'Thriller']
# 4  330457               ['Adventure', 'Animation', 'Family']
# 6  458897                  ['Action', 'Adventure', 'Comedy']
#
#             original_title                    title release_date  popularity  \
# 1  Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04     272.710
# 2                 Ad Astra                 Ad Astra   2019-09-17     271.489
# 3                      기생충                 Parasite   2019-05-30     148.987
# 4                Frozen II                Frozen II   2019-11-20     124.257
# 6         Charlie's Angels         Charlie's Angels   2019-11-14     112.825
#
#    vote_average  vote_count           budget            revenue    imdb_id  \
# 1          68.0        1901  $125,000,000.00    $310,830,000.00  tt7975244
# 2          60.0        2483   $87,500,000.00    $127,175,922.00  tt2935510
# 3          86.0        4756   $11,363,000.00    $201,055,038.00  tt6751668
# 4          71.0        2614   $33,000,000.00  $1,330,764,959.00  tt4520988
# 6          64.0         556   $48,000,000.00     $70,960,003.00  tt5033998
#
#              originalTitle  startYear                      genres  \
# 1  Jumanji: The Next Level     2019.0     Action,Adventure,Comedy
# 2                 Ad Astra     2019.0     Adventure,Drama,Mystery
# 3             Gisaengchung     2019.0       Comedy,Drama,Thriller
# 4                Frozen II     2019.0  Adventure,Animation,Comedy
# 6         Charlie's Angels     2019.0     Action,Adventure,Comedy
#
#    averageRating  numVotes
# 1            6.9     90466
# 2            6.6    147305
# 3            8.6    288268
# 4            7.1     77968
# 6            4.4     27350

# %%
df_tot.sort_values(by=['revenue'], ascending=False)
# Out:
#           id                                          genre_ids  \
# 2404  271404  ['Action', 'Adventure', 'Horror', 'Science Fic...
# 356   420814       ['Adventure', 'Comedy', 'Fantasy', 'Family']
# 3545  261023                                 ['Crime', 'Drama']
# 3556  298312                  ['Horror', 'Mystery', 'Thriller']
# 3555  309809    ['Adventure', 'Animation', 'Fantasy', 'Family']
# ...      ...                                                ...
# 2068  366170                         ['Adventure', 'Animation']
# 2597  393562                              ['Crime', 'Thriller']
# 90    440762                                         ['Comedy']
# 272   474764                    ['Drama', 'Horror', 'Thriller']
# 2134  468284                                 ['Drama', 'Crime']
#
#                          original_title  \
# 2404                     Beyond Skyline
# 356                   Christopher Robin
# 3545                         Black Mass
# 3556                          The Visit
# 3555                  The Little Prince
# ...                                 ...
# 2068  遊☆戯☆王 THE DARK SIDE OF DIMENSIONS
# 2597                       रमन राघव २.०
# 90            Jay and Silent Bob Reboot
# 272                           The Lodge
# 2134                          L'Insulte
#
#                                        title release_date  popularity  \
# 2404                          Beyond Skyline   2017-10-20       6.148
# 356                        Christopher Robin   2018-08-02      11.362
# 3545                              Black Mass   2015-09-04      13.552
# 3556                               The Visit   2015-09-10      12.253
# 3555                       The Little Prince   2015-07-29      17.065
# ...                                      ...          ...         ...
# 2068  Yu-Gi-Oh!: The Dark Side of Dimensions   2016-04-23       9.649
# 2597                        Raman Raghav 2.0   2016-06-24       4.183
# 90                 Jay and Silent Bob Reboot   2019-10-15      23.762
# 272                                The Lodge   2019-12-06      13.517
# 2134                              The Insult   2017-09-14       6.103
#
#       vote_average  vote_count          budget         revenue    imdb_id  \
# 2404          50.0         537  $20,000,000.00     $992,181.00  tt1724970
# 356           74.0        1672  $75,000,000.00  $99,138,899.00  tt4575576
# 3545          64.0        2221  $53,000,000.00  $98,837,872.00  tt1355683
# 3556          62.0        2968   $5,000,000.00  $98,450,062.00  tt3567288
# 3555          76.0        1709  $64,000,000.00  $97,571,250.00  tt1754656
# ...            ...         ...             ...             ...        ...
# 2068          68.0          90           $0.00   $1,015,339.00  tt4273562
# 2597          74.0          59     $521,873.00   $1,013,926.00  tt5662932
# 90            61.0          99           $0.00   $1,011,305.00  tt6521876
# 272           69.0          35           $0.00   $1,005,439.00  tt7347846
# 2134          76.0         259   $3,000,000.00   $1,001,305.00  tt7048622
#
#                                originalTitle  startYear  \
# 2404                          Beyond Skyline     2017.0
# 356                        Christopher Robin     2018.0
# 3545                              Black Mass     2015.0
# 3556                               The Visit     2015.0
# 3555                         Le Petit Prince     2015.0
# ...                                      ...        ...
# 2068  Yu-Gi-Oh!: The Dark Side of Dimensions     2016.0
# 2597                        Raman Raghav 2.0     2016.0
# 90                 Jay and Silent Bob Reboot     2019.0
# 272                                The Lodge     2019.0
# 2134                               L'insulte     2017.0
#
#                          genres  averageRating  numVotes
# 2404    Action,Adventure,Horror            5.3     16556
# 356      Adventure,Comedy,Drama            7.3     61631
# 3545      Biography,Crime,Drama            6.9    160777
# 3556    Horror,Mystery,Thriller            6.2    107000
# 3555  Adventure,Animation,Drama            7.7     52727
# ...                         ...            ...       ...
# 2068  Adventure,Animation,Drama            7.1      2286
# 2597       Crime,Drama,Thriller            7.3     11516
# 90                       Comedy            5.8     10287
# 272       Drama,Horror,Thriller            6.6      2847
# 2134       Crime,Drama,Thriller            7.7     12624
#
# [1301 rows x 16 columns]

# %%
# Out:
# id                  int64
# genre_ids          object
# original_title     object
# title              object
# release_date       object
# popularity        float64
# vote_average      float64
# vote_count          int64
# budget             object
# revenue            object
# imdb_id            object
# originalTitle      object
# startYear         float64
# genres             object
# averageRating     float64
# numVotes            int64
# dtype: object

# %%
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','').replace('$', '')
    return float(new_val)

df_tot['budget']=df_tot['budget'].apply(convert_currency)

# %%
df_tot
# Out:
#           id                                          genre_ids  \
# 1     512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2     419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3     496243                    ['Comedy', 'Drama', 'Thriller']
# 4     330457               ['Adventure', 'Animation', 'Family']
# 6     458897                  ['Action', 'Adventure', 'Comedy']
# ...      ...                                                ...
# 4267  338065           ['Drama', 'Family', 'Romance', 'Comedy']
# 4315  323260                                          ['Drama']
# 4324  315575                                          ['Drama']
# 4365  366755                                         ['Comedy']
# 4383  352162                                          ['Drama']
#
#                       original_title                    title release_date  \
# 1            Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04
# 2                           Ad Astra                 Ad Astra   2019-09-17
# 3                                기생충                 Parasite   2019-05-30
# 4                          Frozen II                Frozen II   2019-11-20
# 6                   Charlie's Angels         Charlie's Angels   2019-11-14
# ...                              ...                      ...          ...
# 4267                   दिल धड़कने दो          Dil Dhadakne Do   2015-06-04
# 4315                              鴨王               The Gigolo   2015-01-29
# 4324  Trois souvenirs de ma jeunesse           My Golden Days   2015-05-20
# 4365                  Fashion Chicks           Fashion Chicks   2015-12-02
# 4383                      Desde allá                From Afar   2016-01-21
#
#       popularity  vote_average  vote_count       budget            revenue  \
# 1        272.710          68.0        1901  125000000.0    $310,830,000.00
# 2        271.489          60.0        2483   87500000.0    $127,175,922.00
# 3        148.987          86.0        4756   11363000.0    $201,055,038.00
# 4        124.257          71.0        2614   33000000.0  $1,330,764,959.00
# 6        112.825          64.0         556   48000000.0     $70,960,003.00
# ...          ...           ...         ...          ...                ...
# 4267       4.933          69.0          74   13000000.0     $22,000,000.00
# 4315       3.596          47.0           7          0.0        $709,136.00
# 4324       4.922          68.0          93          0.0        $269,144.00
# 4365       3.712          61.0          62     450000.0      $1,500,000.00
# 4383       2.917          62.0          61          0.0         $30,169.00
#
#         imdb_id                   originalTitle  startYear  \
# 1     tt7975244         Jumanji: The Next Level     2019.0
# 2     tt2935510                        Ad Astra     2019.0
# 3     tt6751668                    Gisaengchung     2019.0
# 4     tt4520988                       Frozen II     2019.0
# 6     tt5033998                Charlie's Angels     2019.0
# ...         ...                             ...        ...
# 4267  tt4110568                 Dil Dhadakne Do     2015.0
# 4315  tt4539508                        Aap wong     2015.0
# 4324  tt4048050  Trois souvenirs de ma jeunesse     2015.0
# 4365  tt4307968                  Fashion Chicks     2015.0
# 4383  tt4721400                      Desde allá     2015.0
#
#                           genres  averageRating  numVotes
# 1        Action,Adventure,Comedy            6.9     90466
# 2        Adventure,Drama,Mystery            6.6    147305
# 3          Comedy,Drama,Thriller            8.6    288268
# 4     Adventure,Animation,Comedy            7.1     77968
# 6        Action,Adventure,Comedy            4.4     27350
# ...                          ...            ...       ...
# 4267        Comedy,Drama,Romance            6.8     13507
# 4315        Comedy,Drama,Romance            4.4       335
# 4324               Drama,Romance            6.8      2980
# 4365              Comedy,Romance            5.2       287
# 4383               Drama,Romance            6.6      3175
#
# [1301 rows x 16 columns]

# %%
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','').replace('$', '')
    return float(new_val)

df_tot['revenue']=df_tot['revenue'].apply(convert_currency)

# %%
df_tot
# Out:
#           id                                          genre_ids  \
# 1     512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2     419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3     496243                    ['Comedy', 'Drama', 'Thriller']
# 4     330457               ['Adventure', 'Animation', 'Family']
# 6     458897                  ['Action', 'Adventure', 'Comedy']
# ...      ...                                                ...
# 4267  338065           ['Drama', 'Family', 'Romance', 'Comedy']
# 4315  323260                                          ['Drama']
# 4324  315575                                          ['Drama']
# 4365  366755                                         ['Comedy']
# 4383  352162                                          ['Drama']
#
#                       original_title                    title release_date  \
# 1            Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04
# 2                           Ad Astra                 Ad Astra   2019-09-17
# 3                                기생충                 Parasite   2019-05-30
# 4                          Frozen II                Frozen II   2019-11-20
# 6                   Charlie's Angels         Charlie's Angels   2019-11-14
# ...                              ...                      ...          ...
# 4267                   दिल धड़कने दो          Dil Dhadakne Do   2015-06-04
# 4315                              鴨王               The Gigolo   2015-01-29
# 4324  Trois souvenirs de ma jeunesse           My Golden Days   2015-05-20
# 4365                  Fashion Chicks           Fashion Chicks   2015-12-02
# 4383                      Desde allá                From Afar   2016-01-21
#
#       popularity  vote_average  vote_count       budget       revenue  \
# 1        272.710          68.0        1901  125000000.0  3.108300e+08
# 2        271.489          60.0        2483   87500000.0  1.271759e+08
# 3        148.987          86.0        4756   11363000.0  2.010550e+08
# 4        124.257          71.0        2614   33000000.0  1.330765e+09
# 6        112.825          64.0         556   48000000.0  7.096000e+07
# ...          ...           ...         ...          ...           ...
# 4267       4.933          69.0          74   13000000.0  2.200000e+07
# 4315       3.596          47.0           7          0.0  7.091360e+05
# 4324       4.922          68.0          93          0.0  2.691440e+05
# 4365       3.712          61.0          62     450000.0  1.500000e+06
# 4383       2.917          62.0          61          0.0  3.016900e+04
#
#         imdb_id                   originalTitle  startYear  \
# 1     tt7975244         Jumanji: The Next Level     2019.0
# 2     tt2935510                        Ad Astra     2019.0
# 3     tt6751668                    Gisaengchung     2019.0
# 4     tt4520988                       Frozen II     2019.0
# 6     tt5033998                Charlie's Angels     2019.0
# ...         ...                             ...        ...
# 4267  tt4110568                 Dil Dhadakne Do     2015.0
# 4315  tt4539508                        Aap wong     2015.0
# 4324  tt4048050  Trois souvenirs de ma jeunesse     2015.0
# 4365  tt4307968                  Fashion Chicks     2015.0
# 4383  tt4721400                      Desde allá     2015.0
#
#                           genres  averageRating  numVotes
# 1        Action,Adventure,Comedy            6.9     90466
# 2        Adventure,Drama,Mystery            6.6    147305
# 3          Comedy,Drama,Thriller            8.6    288268
# 4     Adventure,Animation,Comedy            7.1     77968
# 6        Action,Adventure,Comedy            4.4     27350
# ...                          ...            ...       ...
# 4267        Comedy,Drama,Romance            6.8     13507
# 4315        Comedy,Drama,Romance            4.4       335
# 4324               Drama,Romance            6.8      2980
# 4365              Comedy,Romance            5.2       287
# 4383               Drama,Romance            6.6      3175
#
# [1301 rows x 16 columns]

# %%
df_tot['Gross Profit']= df_tot.revenue-df_tot.budget

# %%
df_tot
# Out:
#           id                                          genre_ids  \
# 1     512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2     419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3     496243                    ['Comedy', 'Drama', 'Thriller']
# 4     330457               ['Adventure', 'Animation', 'Family']
# 6     458897                  ['Action', 'Adventure', 'Comedy']
# ...      ...                                                ...
# 4267  338065           ['Drama', 'Family', 'Romance', 'Comedy']
# 4315  323260                                          ['Drama']
# 4324  315575                                          ['Drama']
# 4365  366755                                         ['Comedy']
# 4383  352162                                          ['Drama']
#
#                       original_title                    title release_date  \
# 1            Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04
# 2                           Ad Astra                 Ad Astra   2019-09-17
# 3                                기생충                 Parasite   2019-05-30
# 4                          Frozen II                Frozen II   2019-11-20
# 6                   Charlie's Angels         Charlie's Angels   2019-11-14
# ...                              ...                      ...          ...
# 4267                   दिल धड़कने दो          Dil Dhadakne Do   2015-06-04
# 4315                              鴨王               The Gigolo   2015-01-29
# 4324  Trois souvenirs de ma jeunesse           My Golden Days   2015-05-20
# 4365                  Fashion Chicks           Fashion Chicks   2015-12-02
# 4383                      Desde allá                From Afar   2016-01-21
#
#       popularity  vote_average  vote_count       budget       revenue  \
# 1        272.710          68.0        1901  125000000.0  3.108300e+08
# 2        271.489          60.0        2483   87500000.0  1.271759e+08
# 3        148.987          86.0        4756   11363000.0  2.010550e+08
# 4        124.257          71.0        2614   33000000.0  1.330765e+09
# 6        112.825          64.0         556   48000000.0  7.096000e+07
# ...          ...           ...         ...          ...           ...
# 4267       4.933          69.0          74   13000000.0  2.200000e+07
# 4315       3.596          47.0           7          0.0  7.091360e+05
# 4324       4.922          68.0          93          0.0  2.691440e+05
# 4365       3.712          61.0          62     450000.0  1.500000e+06
# 4383       2.917          62.0          61          0.0  3.016900e+04
#
#         imdb_id                   originalTitle  startYear  \
# 1     tt7975244         Jumanji: The Next Level     2019.0
# 2     tt2935510                        Ad Astra     2019.0
# 3     tt6751668                    Gisaengchung     2019.0
# 4     tt4520988                       Frozen II     2019.0
# 6     tt5033998                Charlie's Angels     2019.0
# ...         ...                             ...        ...
# 4267  tt4110568                 Dil Dhadakne Do     2015.0
# 4315  tt4539508                        Aap wong     2015.0
# 4324  tt4048050  Trois souvenirs de ma jeunesse     2015.0
# 4365  tt4307968                  Fashion Chicks     2015.0
# 4383  tt4721400                      Desde allá     2015.0
#
#                           genres  averageRating  numVotes  Gross Profit
# 1        Action,Adventure,Comedy            6.9     90466  1.858300e+08
# 2        Adventure,Drama,Mystery            6.6    147305  3.967592e+07
# 3          Comedy,Drama,Thriller            8.6    288268  1.896920e+08
# 4     Adventure,Animation,Comedy            7.1     77968  1.297765e+09
# 6        Action,Adventure,Comedy            4.4     27350  2.296000e+07
# ...                          ...            ...       ...           ...
# 4267        Comedy,Drama,Romance            6.8     13507  9.000000e+06
# 4315        Comedy,Drama,Romance            4.4       335  7.091360e+05
# 4324               Drama,Romance            6.8      2980  2.691440e+05
# 4365              Comedy,Romance            5.2       287  1.050000e+06
# 4383               Drama,Romance            6.6      3175  3.016900e+04
#
# [1301 rows x 17 columns]

# %%
df_tot.drop(df_tot.index[df_tot['budget'] == 0], inplace = True) # Dropping a 'budget' values that are $0.

# %%
df_tot.to_csv('df_tot.csv')

# %%
df_tot['Gross Profit']= df_tot.revenue-df_tot.budget    #Creating a 'Gross Profit' column

# %%
df_tot.head()
# Out:
#        id                                          genre_ids  \
# 1  512200       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 2  419704  ['Adventure', 'Drama', 'Mystery', 'Science Fic...
# 3  496243                    ['Comedy', 'Drama', 'Thriller']
# 4  330457               ['Adventure', 'Animation', 'Family']
# 6  458897                  ['Action', 'Adventure', 'Comedy']
#
#             original_title                    title release_date  popularity  \
# 1  Jumanji: The Next Level  Jumanji: The Next Level   2019-12-04     272.710
# 2                 Ad Astra                 Ad Astra   2019-09-17     271.489
# 3                      기생충                 Parasite   2019-05-30     148.987
# 4                Frozen II                Frozen II   2019-11-20     124.257
# 6         Charlie's Angels         Charlie's Angels   2019-11-14     112.825
#
#    vote_average  vote_count       budget       revenue    imdb_id  \
# 1          68.0        1901  125000000.0  3.108300e+08  tt7975244
# 2          60.0        2483   87500000.0  1.271759e+08  tt2935510
# 3          86.0        4756   11363000.0  2.010550e+08  tt6751668
# 4          71.0        2614   33000000.0  1.330765e+09  tt4520988
# 6          64.0         556   48000000.0  7.096000e+07  tt5033998
#
#              originalTitle  startYear                      genres  \
# 1  Jumanji: The Next Level     2019.0     Action,Adventure,Comedy
# 2                 Ad Astra     2019.0     Adventure,Drama,Mystery
# 3             Gisaengchung     2019.0       Comedy,Drama,Thriller
# 4                Frozen II     2019.0  Adventure,Animation,Comedy
# 6         Charlie's Angels     2019.0     Action,Adventure,Comedy
#
#    averageRating  numVotes  Gross Profit
# 1            6.9     90466  1.858300e+08
# 2            6.6    147305  3.967592e+07
# 3            8.6    288268  1.896920e+08
# 4            7.1     77968  1.297765e+09
# 6            4.4     27350  2.296000e+07

# %%
df_10=df_tot.sort_values(by=['averageRating', 'Gross Profit'], ascending=False).head(10) # Creating a dataframe for movies with highest rating and highest gross product.

# %%
df_100=df_tot.sort_values(by=['Gross Profit'], ascending=False).head(100) # Creating a dataframe for movies with highest rating and highest gross product.

# %%
df_10.to_csv('df_10.csv')

# %%
df_100.to_csv('df_100.csv')

# %%
df_10
# Out:
#           id                                          genre_ids  \
# 10    475557                     ['Crime', 'Drama', 'Thriller']
# 3     496243                    ['Comedy', 'Drama', 'Thriller']
# 41    299534         ['Action', 'Adventure', 'Science Fiction']
# 11    299536         ['Action', 'Adventure', 'Science Fiction']
# 1664  354912  ['Animation', 'Family', 'Comedy', 'Adventure',...
# 2764  360814                                ['Action', 'Drama']
# 29    324857  ['Action', 'Adventure', 'Animation', 'Comedy',...
# 13    530915                         ['Action', 'Drama', 'War']
# 253   517814                                          ['Drama']
# 697   534780                              ['Crime', 'Thriller']
#
#                          original_title                              title  \
# 10                                Joker                              Joker
# 3                                   기생충                           Parasite
# 41                    Avengers: Endgame                  Avengers: Endgame
# 11               Avengers: Infinity War             Avengers: Infinity War
# 1664                               Coco                               Coco
# 2764                               दंगल                             Dangal
# 29    Spider-Man: Into the Spider-Verse  Spider-Man: Into the Spider-Verse
# 13                                 1917                               1917
# 253                            کفرناحوم                          Capernaum
# 697                             अंधाधुन                          Andhadhun
#
#      release_date  popularity  vote_average  vote_count       budget  \
# 10     2019-10-02      98.649          82.0        9548   55000000.0
# 3      2019-05-30     148.987          86.0        4756   11363000.0
# 41     2019-04-24      38.570          83.0       11389  356000000.0
# 11     2018-04-25      84.768          83.0       16897  300000000.0
# 1664   2017-10-27      23.123          82.0       10352  175000000.0
# 2764   2016-12-21      10.063          80.0         415   10400000.0
# 29     2018-12-06      44.866          84.0        6424   90000000.0
# 13     2019-12-10      70.660          80.0        2963  100000000.0
# 253    2018-10-06      19.380          83.0         622    4000000.0
# 697    2018-10-05       9.568          78.0         142    4500000.0
#
#            revenue    imdb_id                      originalTitle  startYear  \
# 10    1.073699e+09  tt7286456                              Joker     2019.0
# 3     2.010550e+08  tt6751668                       Gisaengchung     2019.0
# 41    2.797801e+09  tt4154796                  Avengers: Endgame     2019.0
# 11    2.046240e+09  tt4154756             Avengers: Infinity War     2018.0
# 1664  8.005260e+08  tt2380307                               Coco     2017.0
# 2764  3.100000e+08  tt5074352                             Dangal     2016.0
# 29    3.754504e+08  tt4633694  Spider-Man: Into the Spider-Verse     2018.0
# 13    2.004833e+08  tt8579674                               1917     2019.0
# 253   6.497893e+07  tt8267604                         Capharnaüm     2018.0
# 697   4.000000e+07  tt8108198                          Andhadhun     2018.0
#
#                           genres  averageRating  numVotes  Gross Profit
# 10          Crime,Drama,Thriller            8.6    698168  1.018699e+09
# 3          Comedy,Drama,Thriller            8.6    288268  1.896920e+08
# 41        Action,Adventure,Drama            8.5    674091  2.441801e+09
# 11       Action,Adventure,Sci-Fi            8.5    750111  1.746240e+09
# 1664  Adventure,Animation,Family            8.4    322211  6.255260e+08
# 2764      Action,Biography,Drama            8.4    136219  2.996000e+08
# 29    Action,Adventure,Animation            8.4    298350  2.854504e+08
# 13                     Drama,War            8.4    202702  1.004833e+08
# 253                        Drama            8.4     38909  6.097893e+07
# 697               Crime,Thriller            8.3     56121  3.550000e+07

# %%
df_10.plot.bar(x='bk', y='Gross Profit')

# %%
df_10['genre_ids'].str.get('')
# Out:
# 10     NaN
# 3      NaN
# 41     NaN
# 11     NaN
# 1664   NaN
# 2764   NaN
# 29     NaN
# 13     NaN
# 253    NaN
# 697    NaN
# Name: genre_ids, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-66cacf2f71e7> in <module>
# ----> 1 df_10['genre_ids'].value_count(df_10['genre_ids']=='Action')
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df_act = df_10[df_10['genres'] =='Action']

# %%
df_10['genres'].str.split()
# Out:
# 10            [Crime,Drama,Thriller]
# 3            [Comedy,Drama,Thriller]
# 41          [Action,Adventure,Drama]
# 11         [Action,Adventure,Sci-Fi]
# 1664    [Adventure,Animation,Family]
# 2764        [Action,Biography,Drama]
# 29      [Action,Adventure,Animation]
# 13                       [Drama,War]
# 253                          [Drama]
# 697                 [Crime,Thriller]
# Name: genres, dtype: object

# %%
filter2 = df_10["genre_ids"].isin(['Action'])

# %%
filter2
# Out:
# 10      False
# 3       False
# 41      False
# 11      False
# 1664    False
# 2764    False
# 29      False
# 13      False
# 253     False
# 697     False
# Name: genre_ids, dtype: bool

# %%
count = df_10.groupby(['genre_ids']).count()

# %%
count
# Out:
#                                                     id  original_title  title  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...   1               1      1
# ['Action', 'Adventure', 'Science Fiction']           2               2      2
# ['Action', 'Drama', 'War']                           1               1      1
# ['Action', 'Drama']                                  1               1      1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...   1               1      1
# ['Comedy', 'Drama', 'Thriller']                      1               1      1
# ['Crime', 'Drama', 'Thriller']                       1               1      1
# ['Crime', 'Thriller']                                1               1      1
# ['Drama']                                            1               1      1
#
#                                                     release_date  popularity  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...             1           1
# ['Action', 'Adventure', 'Science Fiction']                     2           2
# ['Action', 'Drama', 'War']                                     1           1
# ['Action', 'Drama']                                            1           1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...             1           1
# ['Comedy', 'Drama', 'Thriller']                                1           1
# ['Crime', 'Drama', 'Thriller']                                 1           1
# ['Crime', 'Thriller']                                          1           1
# ['Drama']                                                      1           1
#
#                                                     vote_average  vote_count  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...             1           1
# ['Action', 'Adventure', 'Science Fiction']                     2           2
# ['Action', 'Drama', 'War']                                     1           1
# ['Action', 'Drama']                                            1           1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...             1           1
# ['Comedy', 'Drama', 'Thriller']                                1           1
# ['Crime', 'Drama', 'Thriller']                                 1           1
# ['Crime', 'Thriller']                                          1           1
# ['Drama']                                                      1           1
#
#                                                     budget  revenue  imdb_id  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...       1        1        1
# ['Action', 'Adventure', 'Science Fiction']               2        2        2
# ['Action', 'Drama', 'War']                               1        1        1
# ['Action', 'Drama']                                      1        1        1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...       1        1        1
# ['Comedy', 'Drama', 'Thriller']                          1        1        1
# ['Crime', 'Drama', 'Thriller']                           1        1        1
# ['Crime', 'Thriller']                                    1        1        1
# ['Drama']                                                1        1        1
#
#                                                     originalTitle  startYear  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...              1          1
# ['Action', 'Adventure', 'Science Fiction']                      2          2
# ['Action', 'Drama', 'War']                                      1          1
# ['Action', 'Drama']                                             1          1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...              1          1
# ['Comedy', 'Drama', 'Thriller']                                 1          1
# ['Crime', 'Drama', 'Thriller']                                  1          1
# ['Crime', 'Thriller']                                           1          1
# ['Drama']                                                       1          1
#
#                                                     genres  averageRating  \
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...       1              1
# ['Action', 'Adventure', 'Science Fiction']               2              2
# ['Action', 'Drama', 'War']                               1              1
# ['Action', 'Drama']                                      1              1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...       1              1
# ['Comedy', 'Drama', 'Thriller']                          1              1
# ['Crime', 'Drama', 'Thriller']                           1              1
# ['Crime', 'Thriller']                                    1              1
# ['Drama']                                                1              1
#
#                                                     numVotes  Gross Profit
# genre_ids
# ['Action', 'Adventure', 'Animation', 'Comedy', ...         1             1
# ['Action', 'Adventure', 'Science Fiction']                 2             2
# ['Action', 'Drama', 'War']                                 1             1
# ['Action', 'Drama']                                        1             1
# ['Animation', 'Family', 'Comedy', 'Adventure', ...         1             1
# ['Comedy', 'Drama', 'Thriller']                            1             1
# ['Crime', 'Drama', 'Thriller']                             1             1
# ['Crime', 'Thriller']                                      1             1
# ['Drama']                                                  1             1
