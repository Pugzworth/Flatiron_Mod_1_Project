# %%
import pandas as pd

# %%
df_ww = pd.read_csv('df_ww.csv')  # Cleaning data from BoxOfficeMojo.com

# %%
df_ww.head()
# Out:
#    Unnamed: 0  Rank                              Release Group  \
# 0           0     1            Transformers: Age of Extinction
# 1           1     2  The Hobbit: The Battle of the Five Armies
# 2           2     3                    Guardians of the Galaxy
# 3           3     4                                 Maleficent
# 4           4     5      The Hunger Games: Mockingjay - Part 1
#
#         Worldwide      Domestic      %       Foreign    %.1
# 0  $1,104,054,072  $245,439,076  22.2%  $858,614,996  77.8%
# 1    $956,019,788  $255,119,788  26.7%  $700,900,000  73.3%
# 2    $772,776,600  $333,176,600  43.1%  $439,600,000  56.9%
# 3    $758,410,378  $241,410,378  31.8%  $517,000,000  68.2%
# 4    $755,356,711  $337,135,885  44.6%  $418,220,826  55.4%

# %%
df_ww.shape
# Out:
# (4571, 8)

# %%
df_ww.dtypes
# Out:
# Unnamed: 0        int64
# Rank              int64
# Release Group    object
# Worldwide        object
# Domestic         object
# %                object
# Foreign          object
# %.1              object
# dtype: object

# %%
df_ww = df_ww.drop('Unnamed: 0', axis = 1) #Dropping column 'Unnamed: 0'

# %%
df_ww
# Out:
#       Rank                              Release Group       Worldwide  \
# 0        1            Transformers: Age of Extinction  $1,104,054,072
# 1        2  The Hobbit: The Battle of the Five Armies    $956,019,788
# 2        3                    Guardians of the Galaxy    $772,776,600
# 3        4                                 Maleficent    $758,410,378
# 4        5      The Hunger Games: Mockingjay - Part 1    $755,356,711
# ...    ...                                        ...             ...
# 4566   675               Jimi Hendrix Electric Church          $1,818
# 4567   676                                   Game Day          $1,624
# 4568   677                        The Hours and Times          $1,273
# 4569   678                           The Untold Story            $790
# 4570   679                                 The Portal            $685
#
#           Domestic      %       Foreign    %.1
# 0     $245,439,076  22.2%  $858,614,996  77.8%
# ...

# %%
df_ww = df_ww.drop('%.1', axis = 1) #Dropping column '%.1'

# %%
df_ww
# Out:
#       Rank                              Release Group       Worldwide  \
# 0        1            Transformers: Age of Extinction  $1,104,054,072
# 1        2  The Hobbit: The Battle of the Five Armies    $956,019,788
# 2        3                    Guardians of the Galaxy    $772,776,600
# 3        4                                 Maleficent    $758,410,378
# 4        5      The Hunger Games: Mockingjay - Part 1    $755,356,711
# ...    ...                                        ...             ...
# 4566   675               Jimi Hendrix Electric Church          $1,818
# 4567   676                                   Game Day          $1,624
# 4568   677                        The Hours and Times          $1,273
# 4569   678                           The Untold Story            $790
# 4570   679                                 The Portal            $685
#
#           Domestic      %       Foreign
# 0     $245,439,076  22.2%  $858,614,996
# 1     $255,119,788  26.7%  $700,900,000
# ...

# %%
rank = range(51)

df_ww_1 = df_ww[df_ww['Rank'].isin(rank)] #The top 50 movies for years 2014-2019

# %%
df_ww_1
# Out:
#       Rank                              Release Group       Worldwide  \
# 0        1            Transformers: Age of Extinction  $1,104,054,072
# 1        2  The Hobbit: The Battle of the Five Armies    $956,019,788
# 2        3                    Guardians of the Galaxy    $772,776,600
# 3        4                                 Maleficent    $758,410,378
# 4        5      The Hunger Games: Mockingjay - Part 1    $755,356,711
# ...    ...                                        ...             ...
# 3937    46                        Weathering with You    $186,894,545
# 3938    47                                 Gemini Man    $173,469,516
# 3939    48                          Spies in Disguise    $170,761,448
# 3940    49                                   Hustlers    $157,563,598
# 3941    50                               The Climbers    $156,759,167
#
#           Domestic      %       Foreign
# 0     $245,439,076  22.2%  $858,614,996
# 1     $255,119,788  26.7%  $700,900,000
# ...

# %%
pwd
# Out:
# '/Users/lenaya/DS/Flatiron_Mod_1_Project'

# %%
df_ww_1.to_csv('/Users/lenaya/DS/Flatiron_Mod_1_Project/df_ww_1.csv')
